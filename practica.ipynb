# %% [markdown]
# <a href="https://colab.research.google.com/github/alexthorr/practical_cheminformatics_tutorials/blob/main/practica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('test.csv', index_col=0)

# %%
df.head(5)
# Out:
#               Name Synonyms            Type  Max Phase  Molecular Weight  \
# ChEMBL ID
# CHEMBL1796111  NaN      NaN  Small molecule        NaN            506.07
# CHEMBL1524507  NaN      NaN  Small molecule        NaN            580.15
# CHEMBL1796119  NaN      NaN  Small molecule        NaN            545.71
# CHEMBL1796114  NaN      NaN  Small molecule        NaN            552.14
# CHEMBL1329194  NaN      NaN  Small molecule        NaN            455.62
#
#                Targets  Bioactivities  AlogP  Polar Surface Area  HBA  ...  \
# ChEMBL ID                                                              ...
# CHEMBL1796111        4              7   5.87               52.65    4  ...
# CHEMBL1524507       12             14   5.72               86.79    5  ...
# CHEMBL1796119        1              1   5.06               86.79    5  ...
# CHEMBL1796114        1              1   5.91               75.71    4  ...
# ...

# %%
plt.figure()
plt.hist(df['AlogP'], edgecolor="white", facecolor="black")
# Out:
# (array([ 3.,  0.,  0.,  1.,  0.,  1.,  2., 12., 19.,  9.]),
#  array([-4.28 , -3.148, -2.016, -0.884,  0.248,  1.38 ,  2.512,  3.644,
#          4.776,  5.908,  7.04 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12,8))
plt.hist(df['HBA (Lipinski)'], edgecolor="white", facecolor="black")
# Out:
# (array([ 1.,  6., 20., 16.,  1.,  0.,  0.,  0.,  1.,  2.]),
#  array([ 3. ,  4.3,  5.6,  6.9,  8.2,  9.5, 10.8, 12.1, 13.4, 14.7, 16. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['#RO5 Violations (Lipinski)'])
# Out:
# (array([ 7.,  0.,  0.,  0.,  0., 10.,  0.,  0.,  0., 30.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(16,8))
plt.hist(df['Molecular Weight (Monoisotopic)'], edgecolor='white')
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  0.,  3.,  4., 14., 25.]),
#  array([129.079  , 174.09069, 219.10238, 264.11407, 309.12576, 354.13745,
#         399.14914, 444.16083, 489.17252, 534.18421, 579.1959 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.style.use('_mpl-gallery')

# make data:
x = 0.5 + np.arange(8)
y = [4.8, 5.5, 3.5, 4.6, 6.5, 6.6, 2.6, 3.0]

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
plt.figure(figsize=(12,8))
plt.hist(df['Targets'], edgecolor="white", facecolor="black")
# Out:
# (array([34.,  5.,  4.,  0.,  1.,  1.,  1.,  0.,  0.,  1.]),
#  array([ 1. ,  6.2, 11.4, 16.6, 21.8, 27. , 32.2, 37.4, 42.6, 47.8, 53. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12,7))
plt.hist(df['#RO5 Violations'], facecolor="black", edgecolor="white")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-36b0c212bc08> in <cell line: 3>()
#       1 plt.figure(figsize=(12,7))
#       2 plt.hist(df['#RO5 Violations'], facecolor="black", edgecolor="white")
# ----> 3 plt.xtics(np.arange(0, len(bins)))
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtics'

# %%
a = category1_values = [2, 5, 9]
b = category2_values = [7, 6, 3]
a + b
# Out:
# [2, 5, 9, 7, 6, 3]

# %%
plt.hist(df['Bioactivities'], edgecolor="white", color="black")
# Out:
# (array([43.,  2.,  0.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  35.8,  70.6, 105.4, 140.2, 175. , 209.8, 244.6, 279.4,
#         314.2, 349. ]),
#  <BarContainer object of 10 artists>)

# %%
w = pd.read_csv('iris.csv', index_col=0)
w
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
w.Species
# Out:
# Id
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
w['Species']
# Out:
# Id
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
w['Species'][5]
# Out:
# 'Iris-setosa'

# %%
w.iloc[2]
# Out:
# Sepal Length (cm)            4.7
# Sepal Width (cm)             3.2
# Petal Length (cm)            1.3
# Petal Width (cm)             0.2
# Species              Iris-setosa
# Name: 3, dtype: object

# %%
w.loc[:,['Species', '']]
# Out:
#             Species
# Id
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# ..              ...
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
# 150  Iris-virginica
#
# [150 rows x 1 columns]

# %%
tb = pd.read_csv('tbs.csv', index_col=0, encoding="latin-1")
tb.head()
# Out:
#                            2000   2001   2002   2003   2004   2005    2006  \
# estado
#      Aguascalientes        7349   6904   5582   5262  15794   9258   27562
#      Baja California      11284  12771   9594   7872   4199   3320   30539
#      Baja California Sur   3366   3546   2528   2501   2665   1840   10945
#      Campeche              3515   3766   3682   2930   1743   3062   10546
#      Coahuila             18730  14460  16324  15694   5522  20138  118913
#
#                            2007    2008   2009  ...   2012   2013  2014  \
# estado                                          ...
#      Aguascalientes        5831   29612  50467  ...   6258   1732  1865
#      Baja California      68848   51793  24841  ...  28976   8794  6801
#      Baja California Sur  14031   11888   9773  ...   3163   4078  3588
#      Campeche              3814    1441   1574  ...   6329   1789   301
#      Coahuila             51025  112979  44718  ...  18778  11206  8535
#
# ...

# %%
tb.loc[['2018', '2019', '2020']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
b = a.drop('total')
b
# Out:
#                             2018    2019   2020
# estado
#      Aguascalientes         1741    3096   1733
#      Baja California       32008   41998  17618
#      Baja California Sur    4850    5679   2485
#      Campeche                609     575    170
#      Coahuila              14868   14892   5366
#      Colima                  850    1267    896
#      Chiapas                6722   11345   6009
#      Chihuahua             88092   88212  38545
#      D.F. Norte            15846   11281   3449
#      D.F. Sur              87624   73666  48971
#      Durango                4883    4254   1954
#      Guanajuato            19837   12403   7080
#      Guerrero               6093    6664   2239
#      Hidalgo                9831   12263   7225
#      Jalisco              175719  121710  57183
#      México Oriente        65186   74365  57261
#      México Poniente        4655    5902   3278
#      Michoacán             12410    9159   5539
# ...

# %%
plt.figure(figsize=(12,8))
b.plot.bar()
# Out:
# <Axes: xlabel='estado'>

# %%
drug = pd.read_csv('pp.csv', index_col=0)
drug.head()
# Out:
#                    Name                                             SMILES  \
# ID
# mol-184i     Amantadine                              NC12CC3CC(CC(C3)C1)C2
# mol-203i     Amiodarone   CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# mol-208i    Amodiaquine             CCN(CC)Cc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O
# mol-660i     Bisoprolol                  CC(C)NCC(O)COc1ccc(COCCOC(C)C)cc1
# mol-678i  Bromocriptine  CC(C)C[C@H]1C(=O)N2CCC[C@H]2[C@]2(O)O[C@](NC(=...
#
#           Solubility  MaxEStateIndex  MinEStateIndex  MaxAbsEStateIndex  \
# ID
# mol-184i       -2.19        6.320833        0.300347           6.320833
# mol-203i      -10.40       13.588032        0.015348          13.588032
# mol-208i       -5.49       10.164167        0.322980          10.164167
# mol-660i       -2.09        9.800238       -0.512623           9.800238
# mol-678i       -5.50       14.433114       -2.011308          14.433114
#
#           MinAbsEStateIndex       qed    MolWt  HeavyAtomMolWt  ...  \
# ...

# %%
mw = drug[drug["MW"] > 300]
mw
# Out:
#                        Name  \
# ID
# mol-203i         Amiodarone
# mol-208i        Amodiaquine
# mol-660i         Bisoprolol
# mol-678i      Bromocriptine
# mol-690i      Buprenorphine
# mol-824i    Chlorprothixene
# mol-883i        Clofazimine
# mol-923i           Curcumin
# mol-971i            Danazol
# mol-1198i         Ezetimibe
# mol-1230i         Fentiazac
# mol-1536i     Iopanoic Acid
# mol-1600i      Itraconazole
# mol-1767i        Miconazole
# mol-1769i      Mifepristone
# mol-1957i        Omeprazole
# mol-2166i      Pioglitazone
# mol-2444i           Quinine
# mol-2475i        Raloxifene
# mol-2497i         Rifabutin
# mol-2571i        Saquinavir
# mol-2642i  Sulfadimethoxine
# mol-2694i         Tamoxifen
# mol-2706i       Telmisartan
# mol-2718i       Terfenadine
#
#                                                       SMILES  Solubility  \
# ID
# mol-203i    CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1      -10.40
# ...

# %%
new = drug.loc[drug["MW"] > 200, ["Name","Solubility", "MW"]]
new
# Out:
#                        Name  Solubility          MW
# ID
# mol-203i         Amiodarone      -10.40  645.023690
# mol-208i        Amodiaquine       -5.49  355.145140
# mol-660i         Bisoprolol       -2.09  325.225308
# mol-678i      Bromocriptine       -5.50  653.221282
# mol-690i      Buprenorphine       -6.07  467.303559
# mol-824i    Chlorprothixene       -5.99  315.084848
# mol-883i        Clofazimine       -9.05  472.122152
# mol-923i           Curcumin       -5.36  368.125988
# mol-971i            Danazol       -6.10  337.204179
# mol-983i         Didanosine       -1.24  236.090940
# mol-1042i        Diflunisal       -4.99  250.044151
# mol-1065i   Diphenhydramine       -3.21  255.162314
# mol-1191i         Etoxadrol       -1.96  261.172879
# mol-1198i         Ezetimibe       -4.94  409.148950
# mol-1230i         Fentiazac       -5.84  329.027727
# mol-1536i     Iopanoic Acid       -5.49  570.800223
# mol-1600i      Itraconazole       -8.98  704.239307
# ...

# %%
plt.hist(new['MW'], edgecolor="white", color="black")
# Out:
# (array([6., 5., 6., 3., 5., 1., 1., 3., 0., 1.]),
#  array([201.0360682 , 265.57661226, 330.11715632, 394.65770038,
#         459.19824444, 523.7387885 , 588.27933256, 652.81987662,
#         717.36042068, 781.90096474, 846.4415088 ]),
#  <BarContainer object of 10 artists>)

# %%
new["MW"].describe()
# Out:
# count     31.000000
# mean     416.672351
# std      157.532664
# min      201.036068
# 25%      319.634313
# 50%      368.125988
# 75%      472.644116
# max      846.441509
# Name: MW, dtype: float64
